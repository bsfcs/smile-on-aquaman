# %% [markdown]
# pip install seaborn
# pip install xlrd
#
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# %matplotlib inline

# %%
import pandas as pd

# %%
pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\tanya\anaconda3\envs\geospatial\lib\site-packages (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
smile_on = pd.read_csv('../data/SmileOn11.28.2020.csv', sep = ',', encoding='gbk', skiprows = 2, low_memory=False)
bill = pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017.csv', low_memory=False)
prov_out = pd.read_csv('../data/Provider_Outpatient_Hospital_Charge_Data_by_APC__CY2017.csv')
data_dict = pd.read_excel('../data/Data_Dictionary.xlsx')
city_info = pd.read_csv('../data/500_Cities__Local_Data_for_Better_Health__2019_release.csv')
apc = pd.read_excel('../data/2020_October_Web_Addendum_A.10212020.xlsx', skiprows = 1)
hcpcs = pd.read_excel('../data/2020_October_Web_Addendum_B.10212020.xlsx', skiprows = 2)

# %% [markdown]
# apc.head()

# %% [markdown]
# hcpcs.head()

# %% [markdown]
# data_dict

# %% [markdown]
# smile_on.head()

# %% [markdown]
# smile_on.columns

# %%
so_1 = smile_on[['CallReportNum',
'ReportVersion',
'LinkedToCallReportNum',
'CallDateAndTimeStart',
'CallDateAndTimeEnd',
'CallLength',
'CallerNum',
'CityName',
'CountyName',
'PostalCode',
'EnteredOn',
'Birth Year',
'SMILE ON 60+ Screening - Last Screening Date',
'SMILE ON 60+ Oral Care Encounter - What care was provided to the enrollee? (Select all that apply)',
'SMILE ON 60+ Site Information - Enroller ID',
'SMILE ON 60+ Site Information - Enroller Location',
'SMILE ON 60+ Treatment Plan - Is the treatment plan completed?', 
'SMILE ON 60+ Treatment Plan - Was a treatment plan developed?',
'SMILE ON 60+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)', 
'SMILE ON 60+ Verification of Eligibility - Transportation Arranged',
'SMILE ON 60+ Verification of Eligibility - Verification of Eligibility']]

# %%
so_1.head()
# Out:
#    CallReportNum              ReportVersion  LinkedToCallReportNum  \
# 0       81381827  SMILE ON 60+ Registration                    NaN
# 1       81379177  SMILE ON 60+ Registration                    NaN
# 2       81377435      SMILE ON 60+ Clinical                    NaN
# 3       81375215      SMILE ON 60+ Clinical                    NaN
# 4       81373934      SMILE ON 60+ Clinical                    NaN
#
#   CallDateAndTimeStart CallDateAndTimeEnd  CallLength  CallerNum     CityName  \
# 0     11/25/2020 16:46   11/25/2020 16:48           2    3859874  Springfield
# 1     11/25/2020 15:40   11/25/2020 15:55          15    3859755    Nashville
# 2     11/25/2020 15:02   11/25/2020 15:02           0    2518680  Rogersville
# 3     11/25/2020 14:17   11/25/2020 14:17           0    3231923      Memphis
# 4     11/25/2020 13:50   11/25/2020 13:58           8         -1          NaN
#
#   CountyName  PostalCode  ... Birth Year  \
# 0  Robertson     37172.0  ...       1957
# 1   Davidson     37212.0  ...       1943
# 2    Hawkins     37857.0  ...       1957
# 3     Shelby     38104.0  ...       1953
# 4        NaN         NaN  ...       1953
#
#   SMILE ON 60+ Screening - Last Screening Date  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                   11/25/2020
#
#   SMILE ON 60+ Oral Care Encounter - What care was provided to the enrollee? (Select all that apply)  \
# 0                                                NaN
# 1                                                NaN
# 2  5650 - Add tooth to existing partial denture - 30
# 3  No Code - Denture step Mandibular: may be used...
# 4                                                NaN
#
#          SMILE ON 60+ Site Information - Enroller ID  \
# 0  Matthew Walker Comprehensive Health Center Inc...
# 1                                                NaN
# 2          Friends in Need Health Center - Kingsport
# 3          Christ Community Health Services- Frayser
# 4                      Neighborhood Health - Lebanon
#
#   SMILE ON 60+ Site Information - Enroller Location  \
# 0                                     Provider Site
# 1                              Health Assist Office
# 2                                     Provider Site
# 3                                     Provider Site
# 4                                               NaN
#
#   SMILE ON 60+ Treatment Plan - Is the treatment plan completed?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                Yes
# 3                                                NaN
# 4                                                NaN
#
#   SMILE ON 60+ Treatment Plan - Was a treatment plan developed?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                Yes
# 3                                                NaN
# 4                                                Yes
#
#   SMILE ON 60+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                Yes
# 3                                                NaN
# 4                                                 No
#
#   SMILE ON 60+ Verification of Eligibility - Transportation Arranged  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   SMILE ON 60+ Verification of Eligibility - Verification of Eligibility
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                Yes
#
# [5 rows x 21 columns]

# %%
so_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40032 entries, 0 to 40031
# Data columns (total 21 columns):
#  #   Column                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                   --------------  -----
#  0   CallReportNum                                                                                                                                                            40032 non-null  int64
#  1   ReportVersion                                                                                                                                                            40032 non-null  object
#  2   LinkedToCallReportNum                                                                                                                                                    1 non-null      float64
#  3   CallDateAndTimeStart                                                                                                                                                     40032 non-null  object
#  4   CallDateAndTimeEnd                                                                                                                                                       40032 non-null  object
#  5   CallLength                                                                                                                                                               40032 non-null  int64
#  6   CallerNum                                                                                                                                                                40032 non-null  int64
#  7   CityName                                                                                                                                                                 39404 non-null  object
#  8   CountyName                                                                                                                                                               39685 non-null  object
#  9   PostalCode                                                                                                                                                               37392 non-null  float64
#  10  EnteredOn                                                                                                                                                                40032 non-null  object
#  11  Birth Year                                                                                                                                                               40032 non-null  object
#  12  SMILE ON 60+ Screening - Last Screening Date                                                                                                                             14892 non-null  object
#  13  SMILE ON 60+ Oral Care Encounter - What care was provided to the enrollee? (Select all that apply)                                                                       24849 non-null  object
#  14  SMILE ON 60+ Site Information - Enroller ID                                                                                                                              32801 non-null  object
#  15  SMILE ON 60+ Site Information - Enroller Location                                                                                                                        27683 non-null  object
#  16  SMILE ON 60+ Treatment Plan - Is the treatment plan completed?                                                                                                           17535 non-null  object
#  17  SMILE ON 60+ Treatment Plan - Was a treatment plan developed?                                                                                                            17028 non-null  object
#  18  SMILE ON 60+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)  14276 non-null  object
#  19  SMILE ON 60+ Verification of Eligibility - Transportation Arranged                                                                                                       5825 non-null   object
#  20  SMILE ON 60+ Verification of Eligibility - Verification of Eligibility                                                                                                   8718 non-null   object
# dtypes: float64(2), int64(3), object(16)
# memory usage: 6.4+ MB

# %%
bill.head()

# %%
prov_out.head()
